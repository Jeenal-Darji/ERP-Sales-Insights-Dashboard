# %%
import pandas as pd

# %%
df=pd.read_csv("D:\\INTERNSHIP\\P1\\erp-dashboard\\dataset\\sales1.csv")

# %%
df.head()
# Out:
#          date  product_id  quantity  price
# 0  2024-08-19         107         9  80.07
# 1  2025-04-18         147         4  82.94
# 2  2024-08-11         109        30  92.49
# 3  2025-05-14         111         3  26.16
# 4  2025-04-22         188        30  32.51

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        500 non-null    object
#  1   product_id  500 non-null    int64
#  2   quantity    500 non-null    int64
#  3   price       500 non-null    float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 15.8+ KB

# %%
df["price"].describe()
# Out:
# count    500.000000
# mean      55.789000
# std       26.512797
# min       10.060000
# 25%       31.417500
# 50%       57.025000
# 75%       79.912500
# max       99.870000
# Name: price, dtype: float64

# %%
min_date = df['date'].min()
max_date = df['date'].max()
print("From:", min_date, "to", max_date)
# Out:
# From: 2024-06-29 to 2025-06-28

# %%
df["product_id"].nunique()
# Out:
# 98

# %%
df.groupby('date')['quantity'].sum().plot(title="Quantity Sold Over Time")
# Out:
# <Axes: title={'center': 'Quantity Sold Over Time'}, xlabel='date'>
